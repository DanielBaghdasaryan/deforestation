# %%
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
in_image = gdal.Open("T38TML_20170830T074611_TCI.jp2")
im=in_image.ReadAsArray()
im1=im.transpose()
plt.figure(figsize=(15,15))
plt.imshow(im1)
plt.show()
